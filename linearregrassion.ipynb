# %% [markdown]
# <a href="https://colab.research.google.com/github/GouravJounwal/machine-learning/blob/main/linearregrassion.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print('hello you all')
# Out:
# hello you all

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn import linear_model
# !pip install word2number
from word2number import w2n
# Out:
# ...
#   Preparing metadata (setup.py) ... done
# ...
#   Created wheel for word2number: filename=word2number-1.1-py3-none-any.whl size=5570 sha256=d6e0807088f90e8defaeba0756c559066de91fdb1569bcbd0393f74121010dfd
#   Stored in directory: /root/.cache/pip/wheels/84/ff/26/d3cfbd971e96c5aa3737ecfced81628830d7359b55fbb8ca3b
# Successfully built word2number
# ...

# %%
df=pd.read_csv('/areaprice.csv')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-2-a20cbc18f8da> in <cell line: 1>()
# ----> 1 df=pd.read_csv('/areaprice.csv')
#
# /usr/local/lib/python3.10/dist-packages/pandas/io/parsers/readers.py in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#    1024     kwds.update(kwds_defaults)
#    1025
# ...

# %% [markdown]
# plote scatter plot to just see my ditributiion point

# %%
# %matplotlib inline
plt.xlabel('area')
plt.ylabel('price')
plt.scatter(df.Area, df.Price)

# %%
reg= linear_model.LinearRegression()
reg.fit(df[['Area']], df.Price)
# Out:
# LinearRegression()

# %%
prediction = reg.predict(np.array([[7000]]))
print("Prediction for input:", prediction[0])
# Out:
# Prediction for input 4000: 768312.2546881812
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(

# %%
df = pd.read_csv('/onlyArea.csv')
pridiction= reg.predict(df)
print(pridiction)
# Out:
# ---------------------------------------------------------------------------
# NotFittedError                            Traceback (most recent call last)
# <ipython-input-52-4acea959a4e9> in <cell line: 2>()
#       1 df = pd.read_csv('/onlyArea.csv')
# ----> 2 pridiction= reg.predict(df)
#       3 print(pridiction)
#
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_base.py in predict(self, X)
#     304             Returns predicted values.
#     305         """
# --> 306         return self._decision_function(X)
#     307
#     308     def _set_intercept(self, X_offset, y_offset, X_scale):
#
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_base.py in _decision_function(self, X)
#     281
#     282     def _decision_function(self, X):
# --> 283         check_is_fitted(self)
#     284
#     285         X = self._validate_data(X, accept_sparse=["csr", "csc", "coo"], reset=False)
#
# ...

# %%
df['prices']=pridiction
df.to_csv('pricePridict.csv')

# %%
df=pd.read_csv('/canada_per_capita_income - canada_per_capita_income.csv.csv')

# %%
# %matplotlib inline
plt.xlabel('year')
plt.ylabel('per_cap_income')
plt.scatter(df.year, df.per_cap_income)

# %%
reg= linear_model.LinearRegression()
reg.fit(df[['per_cap_income']], df.year)
# Out:
# LinearRegression()

# %%
income = np.array([[50000]])  # Reshape to a 2D array
prediction = reg.predict(income)

print("Prediction for the income:", prediction[0])
# Out:
# Prediction for the income: 2026.4227434880768
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(

# %% [markdown]
# Lenear regression with multiple variable

# %%
df=pd.read_csv('/content/hiring.csv')
from word2number import w2n

# %%
df.experience = df.experience.fillna("zero")
df
# Out:
#   experience  test_score(out of 10)  interview_score(out of 10)  salary($)
# 0       zero                    8.0                           9      50000
# 1       zero                    8.0                           6      45000
# 2       five                    6.0                           7      60000
# 3        two                   10.0                          10      65000
# 4      seven                    9.0                           6      70000
# 5      three                    7.0                          10      62000
# 6        ten                    NaN                           7      72000
# 7     eleven                    7.0                           8      80000

# %%
import math
median_test_score = math.floor(df['test_score(out of 10)'].mean())
median_test_score
# Out:
# 7

# %%
df['test_score(out of 10)'] = df['test_score(out of 10)'].fillna(median_test_score)
df
# Out:
#   experience  test_score(out of 10)  interview_score(out of 10)  salary($)
# 0       zero                    8.0                           9      50000
# 1       zero                    8.0                           6      45000
# 2       five                    6.0                           7      60000
# 3        two                   10.0                          10      65000
# 4      seven                    9.0                           6      70000
# 5      three                    7.0                          10      62000
# 6        ten                    7.0                           7      72000
# 7     eleven                    7.0                           8      80000

# %%
df['experience'] = df['experience'].apply(w2n.word_to_num)

# %%
reg = linear_model.LinearRegression()
reg.fit(df[['experience','test_score(out of 10)','interview_score(out of 10)']],df['salary($)'])
# Out:
# LinearRegression()

# %%
d=reg.predict([[2,9,6]])
print(d)
# Out:
# [53713.86677124]
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(

# %% [markdown]
# save our trained model and used by object sreg

# %%
import pickle

# %%
with open('reg_pickle','wb') as f:
  pickle.dump(reg,f)
with open('reg_pickle','rb') as f:
  sreg=pickle.load(f)
  sreg.predict([[12,10,10]])
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(

# %% [markdown]
# using joblib for save model

# %%
# !pip install joblib
import joblib
#from sklearn.externals import joblib

# %%
joblib.dump(reg,'reg_joblib')
mg=joblib.load('reg_joblib')
mg.predict([[12,10,10]])
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([93747.79628651])
